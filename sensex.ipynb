# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
sensex = pd.read_csv('/Users/ajaysingh/Desktop/Study/4th Semester/BA ZC417 Financial Risk Analytics/SENSEX.csv',
                     header=0,names=['close','returns'],)

# %%
type(sensex['returns']),type(sensex['close'])
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
type(sensex)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.hist(sensex['returns'])

# %%
# %matplotlib inline

# %%
plt.gca()

# %%
plt.gcf()

# %%
plt.show()

# %%
x = np.linspace(0, 10, 1000)

# %%
print(x)

# %%
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.axis('equal')

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.axis('equal')

# %%
fig, ax = plt.subplots(2)

# %%
fig

# %%
print(fig)
dir(ax)

# %%
ax

# %%
ax[0]

# %%
data = np.random.randn(1000)

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts,bin_edges)

# %%
sensex.index.values
# Out:
# array(['02-Jul-13', '03-Jul-13', '04-Jul-13', ..., '27-Jun-18',
#        '28-Jun-18', '29-Jun-18'], dtype=object)

# %%
plt.plot(sensex['returns'].values)

# %%
plt.plot([sensex.index,sensex['returns']])
# Out:
# ...
#  ...]

# %%
sensex['returns'].plot()[0].get_xdata()

# %%
sensex.index

# %%
plt.show()

# %%
plt.gcf()

# %%
obj1 = pd.Series(['Ajay',1,'A',3])

# %%
obj1.name = 'random'

# %%
obj1.index.name = 'TEST'

# %%
obj2 = pd.Series([1,2,3,4])

# %%
obj1 + obj2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     657             result = expressions.evaluate(op, str_rep, x, y,
# --> 658                                           raise_on_error=True, **eval_kwargs)
#     659         except TypeError:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     210         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 211                          **eval_kwargs)
#     212     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
# ...

# %%
type(obj1)
# Out:
# pandas.core.series.Series

# %%
data = {'Apples': [35,41], 'Bananas':[21,34]}
pd.DataFrame(data,index=['2017 Sales','2018 Sales'])
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
data = {'Flour':'4 cups','Milk':'1 cup','Eggs':'2 large','Spam':'1 can'}
pd.Series(data,name='Dinner')
# Out:
# Eggs     2 large
# Flour     4 cups
# Milk       1 cup
# Spam       1 can
# Name: Dinner, dtype: object

# %%
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
pd.DataFrame([30,21],axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-81ac1e26e7fb> in <module>()
# ----> 1 pd.DataFrame([30,21],axis=0)
#
# TypeError: __init__() got an unexpected keyword argument 'axis'

# %%
a=pd.Series([1,2,3],[4,5,6])

# %%
a.index
# Out:
# Int64Index([4, 5, 6], dtype='int64')

# %%
a.name

# %%
np.arange(6.)
# Out:
# array([ 0.,  1.,  2.,  3.,  4.,  5.])

# %%
help(np.random.rand)
# Out:
# Help on built-in function rand:
#
# rand(...) method of mtrand.RandomState instance
#     rand(d0, d1, ..., dn)
#
#     Random values in a given shape.
#
#     Create an array of the given shape and populate it with
#     random samples from a uniform distribution
#     over ``[0, 1)``.
#
#     Parameters
#     ----------
#     d0, d1, ..., dn : int, optional
#         The dimensions of the returned array, should all be positive.
#         If no argument is given a single Python float is returned.
#
#     Returns
#     -------
#     out : ndarray, shape ``(d0, d1, ..., dn)``
#         Random values.
#
#     See Also
#     --------
#     random
#
#     Notes
#     -----
#     This is a convenience function. If you want an interface that
#     takes a shape-tuple as the first argument, refer to
#     np.random.random_sample .
#
#     Examples
#     --------
#     >>> np.random.rand(3,2)
#     array([[ 0.14022471,  0.96360618],  #random
#            [ 0.37601032,  0.25528411],  #random
# ...

# %%
class A:
    def __init__(self):
        self.multiply(15)
        print(self.i)
 
    def multiply(self, i):
        self.i = 4 * i

class B(A):
    def __init__(self):
        super().__init__()
 
    def multiply(self, i):
        self.i = 2 * i

obj = B()
# Out:
# 30

# %%
people = [input().split() for i in range(int(input()))]
# Out:
# 3
# Mike Thomson 20 M
# Robert Bustle 32 M
# Andria Bustle 30 F

# %%
people.sort(key=lambda x:x[2])

# %%
people
# Out:
# [['Mike', 'Thomson', '20', 'M'],
#  ['Andria', 'Bustle', '30', 'F'],
#  ['Robert', 'Bustle', '32', 'M']]

# %%
import exception
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-90-a5d9f9036399> in <module>()
# ----> 1 import exception
#
# ModuleNotFoundError: No module named 'exception'

# %%
1%0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-92-df01d0140aa2> in <module>()
# ----> 1 1%0
#
# ZeroDivisionError: integer division or modulo by zero

# %%
t[5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-670e16babe19> in <module>()
# ----> 1 t[5]
#
# NameError: name 't' is not defined

# %%
open("ajay.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-94-9275811fc3d0> in <module>()
# ----> 1 open("ajay.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ajay.txt'
